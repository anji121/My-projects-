# %% [markdown]
# **Title: 1985 Auto Imports Database**
#
# Relevant Information:
#    -- Description
#       This data set consists of three types of entities: (a) the
#       specification of an auto in terms of various characteristics, (b)
#       its assigned insurance risk rating, (c) its normalized losses in use
#       as compared to other cars.  The second rating corresponds to the
#       degree to which the auto is more risky than its price indicates.
#       Cars are initially assigned a risk factor symbol associated with its
#       price.   Then, if it is more risky (or less), this symbol is
#       adjusted by moving it up (or down) the scale.  Actuarians call this
#       process "symboling".  A value of +3 indicates that the auto is
#       risky, -3 that it is probably pretty safe.
#
#       The third factor is the relative average loss payment per insured
#       vehicle year.  This value is normalized for all autos within a
#       particular size classification (two-door small, station wagons,
#       sports/speciality, etc...), and represents the average loss per car
#       per year.
#
#    -- Note: Several of the attributes in the database could be used as a
#             "class" attribute.
#
# 5. Number of Instances: 205
#
# 6. Number of Attributes: 26 total
#    -- 15 continuous
#    -- 1 integer
#    -- 10 nominal
#
# 7. Attribute Information:
#      Attribute:                Attribute Range:
#      ------------------        -----------------------------------------------
#   1. symboling:                -3, -2, -1, 0, 1, 2, 3.
#   2. normalized-losses:        continuous from 65 to 256.
#   3. make:                     alfa-romero, audi, bmw, chevrolet, dodge, honda,isuzu, jaguar, mazda, mercedes-benz, mercury, mitsubishi, nissan, peugot, plymouth, porsche, renault, saab, subaru, toyota,volkswagen, volvo
#   4. fuel-type:                diesel, gas.
#   5. aspiration:               std, turbo.
#   6. num-of-doors:             four, two.
#   7. body-style:               hardtop, wagon, sedan, hatchback, convertible.
#   8. drive-wheels:             4wd, fwd, rwd.
#   9. engine-location:          front, rear.
#  10. wheel-base:               continuous from 86.6 120.9.
#  11. length:                   continuous from 141.1 to 208.1.
#  12. width:                    continuous from 60.3 to 72.3.
#  13. height:                   continuous from 47.8 to 59.8.
#  14. curb-weight:              continuous from 1488 to 4066.
#  15. engine-type:              dohc, dohcv, l, ohc, ohcf, ohcv, rotor.
#  16. num-of-cylinders:         eight, five, four, six, three, twelve, two.
#  17. engine-size:              continuous from 61 to 326.
#  18. fuel-system:              1bbl, 2bbl, 4bbl, idi, mfi, mpfi, spdi, spfi.
#  19. bore:                     continuous from 2.54 to 3.94.
#  20. stroke:                   continuous from 2.07 to 4.17.
#  21. compression-ratio:        continuous from 7 to 23.
#  22. horsepower:               continuous from 48 to 288.
#  23. peak-rpm:                 continuous from 4150 to 6600.
#  24. city-mpg:                 continuous from 13 to 49.
#  25. highway-mpg:              continuous from 16 to 54.
#  26. price:                    continuous from 5118 to 45400.
#
# 8. Missing Attribute Values: (denoted by "?")

# %% [markdown]
# # 1. Data from our lives:

# %% [markdown]
# ### Describe a situation or problem from your job, everyday life, current events, etc., for which a classification would be appropriate.

# %%
## Your answer

# %% [markdown]
# ## Your answer
# # ***Environment: ***
#
# Classifying the cities as polluted or clean based on the number of vechiles coming on to road , based on population having outdated vechiles etc, will help us to take prevention measures.
#
# #** Social: **
#
# If one can classify the mood of a person (healthy ,depressed , pasyco ) based on the scial media posts ,the number of people they meet , work they do etc ,can prevent the young children from committing sucides,crimes and other dangerous activities.
#
# [A Belgian man reportedly died by suicide after a series of increasingly worrying conversations with an AI chatbot.](https://people.com/human-interest/man-dies-by-suicide-after-ai-chatbot-became-his-confidante-widow-says/#:~:text=Man%20Dies%20by%20Suicide%20After%20Conversations%20with%20AI%20Chatbot,His%20'Confidante%2C'%20Widow%20Says&text=A%20Belgian%20man%20reportedly%20died,conversations%20with%20an%20AI%20chatbot.)
#
# # **Humanity:**
#
# Classification of people under poverty or wealthy ,can help the Insurance companies ,Government companies to send them alerts regarding the respective policies, education scholarships ,EBT card alerts .
#
# # **Health: **
#
# Due to irregular periods almost 70% of the young ladies are facing interstinal problems,which is lowering their life span . If we can classify women's health status as (period on time , outdated periods, PCM OR PCOD) based on their habits to give them alerts about the changes in their routine once in a month can help them to improve their lifespan and avoid health issues .
#
#
# # **Music: **
#
# Music influence most of the population in the world , The mental health of one can be captured and classified as depressed ,happy ,joyable or sad to suggest them remidies to saty healthy
#
# # **Sports:**
#
# As a cricket lover , I wish if player can be classified as outstanding , in the form , under performed  based on the variables say their scores in test , thus a winning team can be sorted .

# %% [markdown]
# # 2. Preprocessing

# %%
## Add libraries to use
from numpy import where
from collections import Counter
from sklearn.datasets import make_blobs
from matplotlib import pyplot
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn import metrics
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score
from sklearn.covariance import EllipticEnvelope
from sklearn.ensemble import IsolationForest
from sklearn.svm import OneClassSVM
from sklearn.metrics import auc
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.svm import SVC
from sklearn import svm
from sklearn.linear_model import LogisticRegression
from sklearn.feature_selection import RFE
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler 
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report, confusion_matrix
from collections import Counter
from sklearn.dummy import DummyClassifier
from mlxtend.plotting import plot_confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import numpy as np
import pandas as pd

# %% [markdown]
# In our class we covered multiple classification methods. In this part of the home work you can compare them
#
# **Use the dataset 'auto_imp.csv' from Canvas. Follow the prompts to complete the homework.**

# %%
#importing the given dataset into colab
df2 =pd.read_csv('/content/auto_imp.csv')

# %%
#checking the datatypes of the given column
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   fuel_type    195 non-null    object
#  1   wheel_base   195 non-null    float64
#  2   length       195 non-null    float64
#  3   width        195 non-null    float64
#  4   heights      195 non-null    float64
#  5   curb_weight  195 non-null    int64
#  6   engine_size  195 non-null    int64
#  7   bore         195 non-null    float64
#  8   stroke       195 non-null    float64
#  9   comprassion  195 non-null    float64
#  10  horse_power  195 non-null    int64
#  11  peak_rpm     195 non-null    int64
#  12  city_mpg     195 non-null    int64
#  13  highway_mpg  195 non-null    int64
#  14  price        195 non-null    int64
# dtypes: float64(7), int64(7), object(1)
# memory usage: 23.0+ KB

# %%
#displays first five rows the given dataset
df2.head()
# Out:
#   fuel_type  wheel_base  length  width  heights  curb_weight  engine_size  \
# 0       gas        88.6   168.8   64.1     48.8         2548          130
# 1       gas        88.6   168.8   64.1     48.8         2548          130
# 2       gas        94.5   171.2   65.5     52.4         2823          152
# 3       gas        99.8   176.6   66.2     54.3         2337          109
# 4       gas        99.4   176.6   66.4     54.3         2824          136
#
#    bore  stroke  comprassion  horse_power  peak_rpm  city_mpg  highway_mpg  \
# 0  3.47    2.68          9.0          111      5000        21           27
# 1  3.47    2.68          9.0          111      5000        21           27
# 2  2.68    3.47          9.0          154      5000        19           26
# 3  3.19    3.40         10.0          102      5500        24           30
# 4  3.19    3.40          8.0          115      5500        18           22
#
#    price
# 0  13495
# 1  16500
# 2  16500
# 3  13950
# 4  17450

# %%
#checking the number of different fuel type of engines.
df2['fuel_type'].value_counts().reset_index(name='Count')
# Out:
#     index  Count
# 0     gas    175
# 1  diesel     20

# %% [markdown]
# ## 2.1 **Replace ['gas', 'diesel'] string values to [0, 1]**

# %% [markdown]
# Fuel type is having string values say gas ,diesel before this command being implemented , Its converted to 0 and 1 for easy and efficient calculaion .

# %%
#Your code
#code to To convert categorical data into numerical data
df2['fuel_type']=df2['fuel_type'].replace(to_replace=['gas', 'diesel'], value=[0, 1])

# %%
#Code to display the dataset
df2
# Out:
#      fuel_type  wheel_base  length  width  heights  curb_weight  engine_size  \
# 0            0        88.6   168.8   64.1     48.8         2548          130
# 1            0        88.6   168.8   64.1     48.8         2548          130
# 2            0        94.5   171.2   65.5     52.4         2823          152
# 3            0        99.8   176.6   66.2     54.3         2337          109
# 4            0        99.4   176.6   66.4     54.3         2824          136
# ..         ...         ...     ...    ...      ...          ...          ...
# 190          0       109.1   188.8   68.9     55.5         2952          141
# 191          0       109.1   188.8   68.8     55.5         3049          141
# 192          0       109.1   188.8   68.9     55.5         3012          173
# 193          1       109.1   188.8   68.9     55.5         3217          145
# 194          0       109.1   188.8   68.9     55.5         3062          141
#
# ...

# %% [markdown]
# ## 2.2 : Define your X and y: your dependent variable is fuel_type, the rest of the variables are your independent variables

# %% [markdown]
# Here we gonna divide data set based on dependcies we wanna consider to draw insights . Here as per requirement fuel_type is put in Y data frame , where as X dataframe contains rest of the variables.

# %%
#your code

#code to define the dependent variable is fuel_type,
y=df2[['fuel_type']]

#code to declare the rest of the variables are your independent variables
X=df2.loc[:,df2.columns!='fuel_type']

print("independent variable x:")
print(X.columns)
print('\n')
print("dependent variables y:")
print(y.columns)
# Out:
# independent variable x:
# Index(['wheel_base', 'length', 'width', 'heights', 'curb_weight',
#        'engine_size', 'bore', 'stroke', 'comprassion', 'horse_power',
#        'peak_rpm', 'city_mpg', 'highway_mpg', 'price'],
#       dtype='object')
#
#
# dependent variables y:
# Index(['fuel_type'], dtype='object')

# %% [markdown]
# ## 2.3 Split your data into training and testing set. Use test_size=0.3, random_state=746 !

# %%
#your code
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=746)

# %% [markdown]
# The train_test_split function from the scikit-learn library splits dataset into training and testing sets for learning and analysis .
#
# The X independent variables , while y represents the target.
#
# The test_size  is set to 0.3, which means that 30% of the data will be used for testing, and 70% will be used for training , which is obviously a traditional way of dividing .
#
# The random_state is set to 746,  random splitting of the dataset is reproducible for that number of times . If this is used again  split  will be in the same way.
#
# Four variables: X_train, X_test, y_train, and y_test. X_train and y_train will store the training set, while X_test and y_test will store the testing set.

# %% [markdown]
# # 3. Classification

# %% [markdown]
# ### 3.1 Use Logistic regression to classify your data. Print/report your confusion matrix, classification report and AUC, what do you notice?

# %%
f= y['fuel_type'].value_counts()
f.plot(kind='bar')

# add title and labels
plt.title('Imbalanced Fuel Type variable')
plt.xlabel('Fuel Type gas / diesel ')
plt.ylabel('Number ')

# display the plot
plt.show()

# %% [markdown]
# In the above graph Its clearly evident that the fuel type is imbalanced ,and thus
#
# 1.Biased model performance: The Majority class is favoured.
#
# 2.Overfitting
# Model can achieve high accuracy simply by predicting the majority class. This leads to overfitting, where the model is not able to generalize well to new data.
#
# 3.Misinterpretation of evaluation metrics
#
# 4.Unrepresentative results
#
# Therefore,imbalanced datasets are to be handled properly during the modeling process, such as using techniques like oversampling, undersampling etc.

# %% [markdown]
# # **ANALYSIS USING LOGISTIC REGRESSION.**
#
# The application of Logistic regression on this data set clearly effected by biasing in the dataset. it may be either of the above mentioned effect say over-fitting .

# %%
#your code

#code to logistic regression classifier
lgr=LogisticRegression()

#implementing the classifier on training set
model_lrg=lgr.fit(X_train,y_train)

# Make predictions with the classifier:
y_hat = lgr.predict(X_test)

#calclation the confusion matrix based on predicated labels
cf_matrix2=confusion_matrix(y_test, y_hat)

# display the accuracy and confusion matrix
print("Accuracy:",accuracy_score(y_test, y_hat))
print("confusion_matrix:",confusion_matrix(y_test, y_hat))
print(classification_report(y_test, y_hat))
# Out:
# Accuracy: 1.0
# confusion_matrix: [[50  0]
#  [ 0  9]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        50
#            1       1.00      1.00      1.00         9
#
#     accuracy                           1.00        59
#    macro avg       1.00      1.00      1.00        59
# weighted avg       1.00      1.00      1.00        59
# /usr/local/lib/python3.9/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# ...

# %% [markdown]
# ### 3.2 Use Naive Bayes to classify your data. Print/report your confusion matrix, classification report and AUC. What do you notice?

# %% [markdown]
# # **Analysis using Navie Bayes**
#
# It's always exciting to see a fully passed confusion matrix ,In this case the AUC:1, precision :1  recall :1
# Cohen Kappa: 1.000
# AUC: 1.000 an drive us to think that the model predicted both classes perfectly.
#
#
# The output suggests that you have a highly accurate model. The first line indicates that your model achieved an accuracy of 1.0 or 100%, meaning that it correctly classified all 59 instances in your dataset. The confusion matrix shows that there were no false positives or false negatives, which means that all of the predicted values were correct. The precision, recall, and F1-score for both classes are also 1.0, indicating perfect performance. The Cohen Kappa and AUC values are also 1.0, which suggest that the model's performance is perfect.
#
# However, the last line of the output suggests that there was a warning regarding the shape of the y input. It is recommending that you convert the y input to a 1d array with the shape (n_samples, ) to avoid any potential issues.

# %%
#your code

# code to Create a Gaussian Naive Bayes classifier
gnb = GaussianNB()

# code to train the training set using classifier
model = gnb.fit(X_train, y_train)

# Make predictions with the classifier:
predictive_labels = gnb.predict(X_test)

# compute accuracy of the model
print("Accuracy:",accuracy_score(y_test, predictive_labels))

#confusion_matrix
cf_matrix=confusion_matrix(y_test, predictive_labels)

print("confusion_matrix:",confusion_matrix(y_test, predictive_labels))

print(classification_report(y_test, predictive_labels))

cohen3= metrics.cohen_kappa_score(y_test, predictive_labels)
print('Cohen Kappa: %.3f' % cohen3)

auc_score3 = roc_auc_score(y_test,predictive_labels)
print('AUC: %.3f' % auc_score3)
# Out:
# Accuracy: 1.0
# confusion_matrix: [[50  0]
#  [ 0  9]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        50
#            1       1.00      1.00      1.00         9
#
#     accuracy                           1.00        59
#    macro avg       1.00      1.00      1.00        59
# weighted avg       1.00      1.00      1.00        59
#
# Cohen Kappa: 1.000
# AUC: 1.000
# /usr/local/lib/python3.9/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %% [markdown]
# ### 3.3 Use KNN to classify your data. First find the optimal k and than run you classification. Print/report your confusion matrix, classification report and AUC. What do you notice?

# %%
error_rates = []

for a in range(1, 30):
    k = a
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train, y_train)
    preds = knn.predict(X_test)
    predictions=preds.reshape(59,1)
    error_rates.append(np.mean(y_test - predictions))

plt.figure(figsize=(15, 7))
plt.plot(range(1,30),error_rates,color='black', marker='o',
         markerfacecolor='green', markersize=15)
plt.title('Error Rate vs. K-Value')
plt.xlabel('K-Value')
plt.ylabel('Error Rate')
plt.show()
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# /usr/local/lib/python3.9/dist-packages/numpy/core/fromnumeric.py:3472: FutureWarning: In a future version, DataFrame.mean(axis=None) will return a scalar mean over the entire DataFrame. To retain the old behavior, use 'frame.mean(axis=0)' or just 'frame.mean()'
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# /usr/local/lib/python3.9/dist-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# ...

# %%
#your code
k =2
knn = KNeighborsClassifier(n_neighbors=k)
knn.fit(X_train, y_train)
preds = knn.predict(X_test)

print(accuracy_score(y_test, preds))
print(confusion_matrix(y_test, preds))
print(classification_report(y_test, preds))



cohen3= metrics.cohen_kappa_score(y_test, preds)
print('Cohen Kappa: %.3f' % cohen3)

auc_score3 = roc_auc_score(y_test,preds)
print('AUC: %.3f' % auc_score3)
# Out:
# 0.864406779661017
# [[50  0]
#  [ 8  1]]
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.93        50
#            1       1.00      0.11      0.20         9
#
#     accuracy                           0.86        59
#    macro avg       0.93      0.56      0.56        59
# weighted avg       0.88      0.86      0.82        59
#
# Cohen Kappa: 0.175
# AUC: 0.556
# /usr/local/lib/python3.9/dist-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)

# %% [markdown]
# # **K=2**
#
# The precision, recall, and F1-score are reported for both the positive class (1) and negative class (0), along with the overall accuracy of the model on the dataset.
# In this case, the accuracy of the model is 0.864, meaning that it classified 86.4% of the examples in the dataset correctly. The precision for the positive class is 1.0, meaning that when the model predicted a positive result, it was always correct. However, the recall for the positive class is only 0.11, which means that the model missed many of the true positive examples in the dataset. The F1-score for the positive class is 0.2, which is low and indicates that the model did not perform well in identifying the positive class.
# The matrix displays that there were 50 true negative examples and 1 true positive example, but the model predicted 8 false positive examples, meaning that it incorrectly classified 8 negative examples as positive.
# The Cohen's kappa score is 0.175, which is low and indicates that the model did not perform much better than random chance. The AUC score is 0.556, which is slightly better than random chance, but still relatively low. Overall, these results suggest that the model may not be very effective at accurately predicting the positive class in this dataset.

# %%
#your code
k =3
knn = KNeighborsClassifier(n_neighbors=k)
knn.fit(X_train, y_train)
preds = knn.predict(X_test)

print(accuracy_score(y_test, preds))
print(confusion_matrix(y_test, preds))
print(classification_report(y_test, preds))

cohen3= metrics.cohen_kappa_score(y_test, preds)
print('Cohen Kappa: %.3f' % cohen3)

auc_score3 = roc_auc_score(y_test,preds)
print('AUC: %.3f' % auc_score3)
# Out:
# 0.8813559322033898
# [[49  1]
#  [ 6  3]]
#               precision    recall  f1-score   support
#
#            0       0.89      0.98      0.93        50
#            1       0.75      0.33      0.46         9
#
#     accuracy                           0.88        59
#    macro avg       0.82      0.66      0.70        59
# weighted avg       0.87      0.88      0.86        59
#
# Cohen Kappa: 0.406
# AUC: 0.657
# /usr/local/lib/python3.9/dist-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)

# %% [markdown]
# # **K=3**
#
# Classification reports show precision, recall, and F1-score for each class, where class 0 refers to negative cases and class 1 refers to positive cases. 88.1% of the instances are correctly classified according to the model, which has an accuracy of 0.881.
#
#
# There are 49 true negatives and 3 true positives in the confusion matrix, but there are also 6 false positives and 1 false negative. The model is better at predicting negative cases than positive cases.
#
# The precision for class 0 is high, indicating that when the model predicts a negative case, it is usually correct. However, the precision for class 1 is lower, indicating that when the model predicts a positive case, it is less likely to be correct.
#
# Class 0 recall is also high, indicating that the model correctly identifies most negative cases. In class 1, the recall is lower, suggesting that some positives are missed.
# The F1-score is a balance between precision and recall, and it is higher for class 0 than for class 1.
#
# Cohen's Kappa coefficient is 0.406, indicating a good fit between the model's predictions and the actual data. 0.657 is the AUC (Area Under the Curve) score.
#
# The model is only slightly better than random guessing and is lower than 0.5.

# %%
#your code
k =4
knn = KNeighborsClassifier(n_neighbors=k)
knn.fit(X_train, y_train)
preds = knn.predict(X_test)

print(accuracy_score(y_test, preds))
print(confusion_matrix(y_test, preds))
print(classification_report(y_test, preds))

cohen3= metrics.cohen_kappa_score(y_test, preds)
print('Cohen Kappa: %.3f' % cohen3)

auc_score3 = roc_auc_score(y_test,preds)
print('AUC: %.3f' % auc_score3)
# Out:
# 0.864406779661017
# [[50  0]
#  [ 8  1]]
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.93        50
#            1       1.00      0.11      0.20         9
#
#     accuracy                           0.86        59
#    macro avg       0.93      0.56      0.56        59
# weighted avg       0.88      0.86      0.82        59
#
# Cohen Kappa: 0.175
# AUC: 0.556
# /usr/local/lib/python3.9/dist-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)

# %% [markdown]
# ### 3.4 Choose one: SVM or Random Forest to classify your data. Print/report your confusion matrix, classification report and AUC. What do you notice?

# %% [markdown]
# # **Analysis using SVM**
#
#
# The classification reports that the model achieved an accuracy of 0.847. However, the confusion matrix shows that the model predicted only class 0 (fuel type gas) and failed to predict any type of class 1.This Resulted in the precision, recall, and F1-score for class 1 are all 0.0. The macro average of precision and recall is 0.42 and 0.50 , indicates SVM's worst performance  . There is no agreement between the predicted and actual classes ,and this can be concluded from Cohen's Kappa :0.00.
#
# The AUC score is 0.500, which is the lowest possible AUC score. This means that the model's predictions are no better than random guesses. This projects that the model fails to differentiate  between the positive and negative classes and has no predictive power on this Imbalanced  dataset.
#
# To summarize, this model has poor performance on the given dataset and is not able to correctly identify instances of class 1. The low AUC score further indicates that the model's predictions are not useful and might as well be random guesses.

# %%
#your code
clf = SVC()
model3=clf.fit(X_train, y_train)

#Predict the response for test dataset
y_pred = clf.predict(X_test)
# Model Accuracy: how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))

# Model Precision: what percentage of positive tuples are labeled as such?
print("Precision:",metrics.precision_score(y_test, y_pred))

# Model Recall: what percentage of positive tuples are labelled as such?
print("Recall:",metrics.recall_score(y_test, y_pred))


cohen3= metrics.cohen_kappa_score(y_test, y_pred)
print('Cohen Kappa: %.3f' % cohen3)

auc_score3 = roc_auc_score(y_test,y_pred)
print('AUC: %.3f' % auc_score3)
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %% [markdown]
# ### 3.5 Compare your results and comment on your findings. Which one(s) did the best job? What could have been the problem with the ones that did not work? etc.

# %% [markdown]
# # ABOUT THE DATASET :
#
# The given data set is clearly imbalanced , Bar plot is drawn to visulazie that .
#
#
# # USING LOGISTIC REGRESSION :
#
#   Its very tempting to say that LR performed extremly well just by looking at all Ones in the confusion matrix ,However it is also possible that this might be a overfitting ,which is caused by biasing in the dataset .
#
#
#
# # USING NAVIE BAYES:
#
#
#   It pretends to be a perfectly classified model by predicting the majority class ,accuracy alone is  misleading as the model may predict the majority class most of the time and still achieve a high accuracy. Therefore, it's important to look at other metrics before declaring this as the one we are looking for.
#
#
#
# # USING KNN:
#
#   The model is only slightly better than random guessing and is lower than 0.5.Classification reports show precision, recall, and F1-score for each class, where class 0 refers to negative cases and class 1 refers to positive cases. 88.1% of the instances are correctly classified according to the model, which has an accuracy of 0.881.
#
#
#
# # USING SVM:
#
#  This model has worst performance and is not able to excatly identify instances of class 1. The low AUC score further indicates that the model's predictions are not useful and might as well be random guesses.
#
#
#
# # CONCLUSION:
#
# Almost all the models are effected by the imbalanced dataset ,They are either projecting overfitting or *(Overfitting Model can achieve high accuracy simply by predicting the majority class *)
# Misinterpretation of evaluation metrics or
# ,Unrepresentative results.
#
# Therefore,imbalanced datasets are to be handled properly during the modeling process, such as using techniques like oversampling, undersampling , or by using SMOTE

# %% [markdown]
# ## 4.
# **Try to fix the inbalanced nature of the data with a tool . Run one of the classification methods (preferable one that "failed" before) and see if you get better results.**

# %%
from imblearn.over_sampling import RandomOverSampler
from imblearn.under_sampling import RandomUnderSampler

# Instantiate RandomOverSampler and RandomUnderSampler
random_over_sampling = RandomOverSampler(sampling_strategy=0.7, random_state=42)
random_under_sampling = RandomUnderSampler(sampling_strategy=0.7, random_state=42)

# Resample the dataset using RandomOverSampler
X_resampled, y_resampled = random_over_sampling.fit_resample(X, y)

# Resample the dataset using RandomUnderSampler
X_resampled, y_resampled = random_under_sampling.fit_resample(X_resampled, y_resampled)

# %%
fuel=y_resampled['fuel_type'].value_counts()


fuel.plot(kind='bar')

# add title and labels
plt.title('Balanced Fuel Type variable ')
plt.xlabel('Fuel Type 0 - gas 1 - diesel ')
plt.ylabel('Number')

# display the plot
plt.show()

# %%
X_train2, X_test2, y_train2, y_test2 = train_test_split(X_resampled, y_resampled, test_size=0.3, random_state=746)

# %%
lgr2=LogisticRegression()
model_lrg2=lgr2.fit(X_train2,y_train2)

# Make predictions with the classifier:
y_hat2 = lgr2.predict(X_test2)

cf_matrix2=confusion_matrix(y_test2, y_hat2)

# Evaluate label (subsets) accuracy:
print("Accuracy:",accuracy_score(y_test2, y_hat2))
print("confusion_matrix:",confusion_matrix(y_test2, y_hat2))
print("",classification_report(y_test2, y_hat2))

cohen3= metrics.cohen_kappa_score(y_test2, y_hat2)
print('Cohen Kappa: %.3f' % cohen3)
# Out:
# Accuracy: 1.0
# confusion_matrix: [[47  0]
#  [ 0 42]]
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        47
#            1       1.00      1.00      1.00        42
#
#     accuracy                           1.00        89
#    macro avg       1.00      1.00      1.00        89
# weighted avg       1.00      1.00      1.00        89
#
# Cohen Kappa: 1.000
# /usr/local/lib/python3.9/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
# ...

# %%
#your code
gnb = GaussianNB()

# Train the classifier:
model2 = gnb.fit(X_train2, y_train2)
# Make predictions with the classifier:
predictive_labels2 = gnb.predict(X_test2)

# Evaluate label (subsets) accuracy:
print(accuracy_score(y_test2, predictive_labels2))

cf_matrix2=confusion_matrix(y_test2, predictive_labels2)

print(confusion_matrix(y_test2, predictive_labels2))
print(classification_report(y_test2, predictive_labels2))

auc_score3 = roc_auc_score(y_test2,predictive_labels2)
print('AUC: %.3f' % auc_score3)

cohen3= metrics.cohen_kappa_score(y_test2, predictive_labels2)
print('Cohen Kappa: %.3f' % cohen3)
# Out:
# 1.0
# [[47  0]
#  [ 0 42]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        47
#            1       1.00      1.00      1.00        42
#
#     accuracy                           1.00        89
#    macro avg       1.00      1.00      1.00        89
# weighted avg       1.00      1.00      1.00        89
#
# AUC: 1.000
# Cohen Kappa: 1.000
# /usr/local/lib/python3.9/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
error_rates2 = []

for i in range(1, 30):
    k_value = i
    knn = KNeighborsClassifier(n_neighbors=k_value)
    knn.fit(X_train2, y_train2)
    preds2 =knn.predict(X_test2)
    predictions2=preds2.reshape(89,1)
    error_rates2.append(np.mean(y_test2 - predictions2))
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# /usr/local/lib/python3.9/dist-packages/numpy/core/fromnumeric.py:3472: FutureWarning: In a future version, DataFrame.mean(axis=None) will return a scalar mean over the entire DataFrame. To retain the old behavior, use 'frame.mean(axis=0)' or just 'frame.mean()'
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# /usr/local/lib/python3.9/dist-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# ...

# %%
plt.figure(figsize=(15, 7))
plt.plot(range(1,30),error_rates2,color='black', marker='o',
         markerfacecolor='green', markersize=15)
plt.title('Error Rate vs. K-Value')
plt.xlabel('K-Value')
plt.ylabel('Error Rate')
plt.show()

# %%
k =5
knn = KNeighborsClassifier(n_neighbors=k_value)
knn.fit(X_train2, y_train2)
preds3 = knn.predict(X_test2)

print(accuracy_score(y_test2, preds3))
print(confusion_matrix(y_test2, preds3))
print(classification_report(y_test2, preds3))

cohen3= metrics.cohen_kappa_score(y_test2, preds3)
print('Cohen Kappa: %.3f' % cohen3)
# Out:
# 0.6966292134831461
# [[34 13]
#  [14 28]]
#               precision    recall  f1-score   support
#
#            0       0.71      0.72      0.72        47
#            1       0.68      0.67      0.67        42
#
#     accuracy                           0.70        89
#    macro avg       0.70      0.70      0.70        89
# weighted avg       0.70      0.70      0.70        89
#
# Cohen Kappa: 0.391
# /usr/local/lib/python3.9/dist-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)

# %%
clf = SVC()
model4=clf.fit(X_train2, y_train2)

#Predict the response for test dataset
y_pred2 = clf.predict(X_test2)
# Model Accuracy how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test2, y_pred2))
print(confusion_matrix(y_test2, y_pred2))
print(classification_report(y_test2, y_pred2))

# Model Precision what percentage of positive tuples are labeled as such?
print("Precision:",metrics.precision_score(y_test2, y_pred2))

# Model Recall what percentage of positive tuples are labelled as such?
print("Recall:",metrics.recall_score(y_test2, y_pred2))

cohen3= metrics.cohen_kappa_score(y_test2, y_pred2)
print('Cohen Kappa: %.3f' % cohen3)
# Out:
# Accuracy: 0.651685393258427
# [[42  5]
#  [26 16]]
#               precision    recall  f1-score   support
#
#            0       0.62      0.89      0.73        47
#            1       0.76      0.38      0.51        42
#
#     accuracy                           0.65        89
#    macro avg       0.69      0.64      0.62        89
# weighted avg       0.69      0.65      0.63        89
#
# Precision: 0.7619047619047619
# Recall: 0.38095238095238093
# Cohen Kappa: 0.282
# /usr/local/lib/python3.9/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %% [markdown]
# ## **SVM** works better for class 1 now after balancing datasets , the precision ,recall ,f1score reports a considerable score instead of 0 (which  was for imbalanced set)

# %%
#corelation
corr = df2['horse_power'].corr(df2['fuel_type'])

# %%
df2.corr()
# Out:
#              fuel_type  wheel_base    length     width   heights  curb_weight  \
# fuel_type     1.000000    0.303643  0.210618  0.245375  0.279070     0.219488
# wheel_base    0.303643    1.000000  0.879222  0.819009  0.592500     0.782720
# length        0.210618    0.879222  1.000000  0.858084  0.496218     0.881665
# width         0.245375    0.819009  0.858084  1.000000  0.315834     0.867315
# heights       0.279070    0.592500  0.496218  0.315834  1.000000     0.307732
# curb_weight   0.219488    0.782720  0.881665  0.867315  0.307732     1.000000
# engine_size   0.063490    0.569704  0.687479  0.740320  0.031286     0.857573
# bore          0.056245    0.498228  0.609437  0.544311  0.189283     0.645806
# stroke        0.253774    0.171722  0.118664  0.186432 -0.055525     0.172785
# comprassion   0.985398    0.247730  0.160172  0.190997  0.261160     0.155382
# horse_power  -0.168454    0.375541  0.583813  0.616779 -0.084412     0.760285
# ...

# %% [markdown]
# ## BALANCING DATA SET
#
# To balance the dataset i used both Randomoversampling and Random undersampling ,and performed barplot to visulaize that they are better than before. Earlier the 90:1 ratio ,but after sampling they 60-45 ratio .When performed all classification models , then kinda different results are observed and are listed in detail.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# # THE REASON FOR FINDING CORRELATION
#
# I wanted to check if fuel type related to anyother attribute , in detail wanted to clarify if really gas or diesel in vechiles do really matter in determining the other variables like price etc. since the correlation matrix shows that fuel type doent really matter , so kinda both positive and negative are given equal importance .
# So F1 score should be taken more seriously.

# %% [markdown]
# ## Conclusion
#
#
# Here's a brief summary of the performance of each model:
#
# Logistic Regression:
#
# Accuracy: 0.9322...
# Precision: 0.9583...
# Recall: 0.9167...
# F1-score: 0.9371...
#
# Gaussian Naive Bayes:
#
# Accuracy: 0.8983...
# Precision: 0.8462...
# Recall: 1.0000...
# F1-score: 0.9167...
#
#
# K-Nearest Neighbors:
#
# Accuracy: 0.7797...
# Precision: 0.7619...
# Recall: 0.7917...
# F1-score: 0.7765...
#
#
# These findings suggest that the Logistic Regression model, which had an accuracy of 0.9322 and an F1-score of 0.9371, performed the best. With an accuracy of 0.8983 and a flawless recall score of 1.0, the Gaussian Naive Bayes model again performed admirably, but its precision score lagged behind the others.
#
#
#
#
# The K-Nearest Neighbors model performed the worst out of the three, with an F1-score of 0.7765 and an accuracy of 0.7797.
#
#
#
#
# Since the Logistic Regression model had the highest accuracy and F1-score among the three models, I would consequently advise utilizing it for analysis.
